# %% [markdown]
# ### 파이썬 라이브러리 불러오기

# %%
# Data Import
import pydsptools.biorad as biorad

# Config
import pydsptools.config.pda as pda

# DSP processing
import pydsp.run.worker
import os
import pathlib as Path

# Analysis
import polars as pl
import pandas as pd

# Visualization
import pydsptools.plot as dspplt

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Script Description
#
# ## [2024-04-23]
#
# * 배경
#     * 이 스크립트는 데이터의 수와 종류가 늘어나고 병합과정이 복잡해짐에 따라 각 데이터가 각 단계에서 올바르게 처리되는지를 알아본다.
#     * baseline fitting 알고리즘의 성능을 측정하는 방법 중 하나인 MuDT의 왜곡 신호를 비교하는 시각화를 수행하기 위해 데이터 엔지니어링이 적절히 수행됐는지 확인해야한다.
#     * MuDT 왜곡 신호란? 하나의 well에서 High Temp에서 양성 Low Temp에서 음성 신호 결과가 나왔을 때, MuDT의 신호 왜곡 현상인 과도한 CR 현상이 발생하는 것을 의미한다.
#     * 각 각의 well에서 High Temp에서 양성 Low Temp에서 음성 신호를 filtering 해야하는데 1개의 well당 Low Temp 신호와 High Temp 신호의 pairing이 전제가 되어야 한다.
# * 목표
#     * `cfx batch analyzer`에서 추출된 신호의 sample size를 확인하고 최종 data 전처리 결과물과 일치하는지 확인한다.
# * 방법
#     * 아래의 각 데이터 항목을 아래의 검증 절차에 따라 수행한다.
#         * [After BPN] RFU: original rfu를 BPN으로 Transformation한 Data
#         * [Modified DSP] Original ABSD: 음성탈락 신호들의 absd-orig을 얻기위해 설정값들을 변경하여 얻은 Data로 음성 데이터에서 **final_ct가 부정확**할 수 있다. (final_ct 부정확 with 설정값 modified)
#         * [Auto] Baseline-Subtracted RFU: pgr-manager의 raw tab 결과 (final_ct 부정확 with 설정값 modified)
#         * [CFX] Baseline-Subtracted RFU: cfx manager의 baseline subtracted data. (final_ct 부정확 with 설정값 modified)
#         * [Strep] Baseline-Subtracted RFU (final_ct 부정확 with 설정값 modified)
#         * [Strep+n] Baseline-Subtracted RFU (final_ct 부정확 with 설정값 modified)
#         * [Control DSP] Baseline-Subtracted RFU (final_ct 정확 with 설정값 intact)
#     * 검증 절차
#         * `1.cfx-to-parquet-converter.ipynb`의 csv에서 parquet의 pcrd 개수, pcrd당 channel당 temperature당 well 개수 확인
#         * `2.dsp-executer.ipynb`의 DSP 실행 후 연산 결과인 parquet의 pcrd 개수, pcrd당 channel당 temperature당 well 개수 확인

# %% [markdown]
# ## 1. CFX의 csv-to-parquet converter 단계

# %% [markdown]
# **1. CSV well 카운트**

# %%
csv_path = './data/GI-B-I/GI-B-I-100/csv'
GIBI_8strip_csv_df = []

channel_mapping = {
    'Cal Red 610': 'Cal Red 610',
    'FAM': 'FAM',
    'HEX': 'HEX',
    'Quasar 670': 'Quasar 670'
}
temperature_mapping = {
    'Amp4': 'Low',
    'Amp5': 'High'
}

def extract_channel(filename):
    for key in channel_mapping:
        if key in filename:
            return channel_mapping[key]
    return 'unexpected'

def extract_temperature(filename):
    for key in temperature_mapping:
        if key in filename:
            return temperature_mapping[key]
    return 'unexpected'

for filename in os.listdir(csv_path):
    if 'Quantification Amplification Results' in filename and filename.endswith('.csv'):
        file_path = os.path.join(csv_path, filename)
        temp = pd.read_csv(file_path)
        temp = temp.iloc[:,1:]
        temp['name'] = filename
        temp['channel'] = extract_channel(filename)
        temp['temperature'] = extract_temperature(filename)
        GIBI_8strip_csv_df.append(temp)

GIBI_8strip_csv_df = pd.concat(GIBI_8strip_csv_df, ignore_index=True)

# 칼럼 재정렬
leading_columns = ['name', 'channel', 'temperature']
other_columns = [col for col in GIBI_8strip_csv_df.columns if col not in leading_columns]
new_order = leading_columns + other_columns
GIBI_8strip_csv_df = GIBI_8strip_csv_df[new_order]

# %%
leading_columns = ['name', 'channel', 'temperature']
leading_columns.append('temp')

aggregated_df = pd.DataFrame()
for well in other_columns[1:]:
    current_columns = leading_columns[:-1] + ['Cycle', well]  # Simplified combining lists
    temp = combined_df[current_columns].groupby(['name', 'channel', 'temperature']).size().reset_index(name='count')
    temp['well'] = well
    aggregated_df = pd.concat([aggregated_df, temp], ignore_index=True)

# %%
well_counts = aggregated_df.groupby(['name', 'channel'])['well'].nunique().reset_index(name='unique_wells')
print(well_counts)
print(well_counts['unique_wells'].unique())
# Out:
#                                                   name      channel  \
# 0    2. admin_2017-05-22 14-06-05_BR101459 GI9801XY...  Cal Red 610
# 1    2. admin_2017-05-22 14-06-05_BR101459 GI9801XY...          FAM
# 2    2. admin_2017-05-22 14-06-05_BR101459 GI9801XY...          HEX
# 3    2. admin_2017-05-22 14-06-05_BR101459 GI9801XY...   Quasar 670
# 4    2. admin_2017-05-22 14-06-05_BR101459 GI9801XY...  Cal Red 610
# ..                                                 ...          ...
# 795  admin_2017-10-27 10-11-31_BR100858 GI9801Y 완제품...   Quasar 670
# 796  admin_2017-10-27 10-11-31_BR100858 GI9801Y 완제품...  Cal Red 610
# 797  admin_2017-10-27 10-11-31_BR100858 GI9801Y 완제품...          FAM
# 798  admin_2017-10-27 10-11-31_BR100858 GI9801Y 완제품...          HEX
# 799  admin_2017-10-27 10-11-31_BR100858 GI9801Y 완제품...   Quasar 670
#
#      unique_wells
# 0              96
# 1              96
# 2              96
# 3              96
# 4              96
# ..            ...
# 795            96
# 796            96
# 797            96
# 798            96
# 799            96
#
# [800 rows x 3 columns]
# [96]

# %%
aggregated_df.groupby(['channel','temperature','count']).size().reset_index(name='n').assign(n=lambda df: df['n'] / 96)
# cycle 45개 protocol : 94개
# cycle 50개 protocol : 6개
# Out:
#         channel temperature  count     n
# 0   Cal Red 610        High     45  94.0
# 1   Cal Red 610        High     50   6.0
# 2   Cal Red 610         Low     45  94.0
# 3   Cal Red 610         Low     50   6.0
# 4           FAM        High     45  94.0
# 5           FAM        High     50   6.0
# 6           FAM         Low     45  94.0
# 7           FAM         Low     50   6.0
# 8           HEX        High     45  94.0
# 9           HEX        High     50   6.0
# 10          HEX         Low     45  94.0
# 11          HEX         Low     50   6.0
# 12   Quasar 670        High     45  94.0
# 13   Quasar 670        High     50   6.0
# 14   Quasar 670         Low     45  94.0
# 15   Quasar 670         Low     50   6.0

# %% [markdown]
# **2. pda-pro의 DSP input의 well 카운트**

# %%
paths
# Out:
# <generator object Path.glob at 0x75449c7ff560>

# %%
parquet_path = './data/GI-B-I/GI-B-I-100/computed/pcr_results/'
paths = Path.Path(f"{parquet_path}").glob("*.parquet")
paths = sorted(list(paths), key=lambda p: p.name)
GIBI_8strip_parquet_df = pd.DataFrame()
for path in paths:
    name = path.name[:-8]
    df = pd.read_parquet(path)
    print({'unique_wells':len(df['well'].unique()),'unique_signals': len(df['well'])/4/2,'name':name}) #모든 pcrd파일들 channel 별로 high, low 짝지어 찍혔음
# Out:
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': '2. admin_2017-05-22 14-06-05_BR101459 GI9801XY MOM 소량 반제품1 민감도(Vpara, CdB, Vchol)'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': '4. admin_2017-05-22 14-38-11_BR101644 GI9801XY MOM 소량 반제품1 민감도(Ahyd, Avero, Sbong)'}
# {'unique_wells': 56, 'unique_signals': 56.0, 'name': '5. admin_2017-05-22 14-40-33_BR101645 GI9801XY MOM 소량 반제품1 민감도(Styphi, IC)'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-23 02-32-41_BR100160_Allplex GI_B1_TCF_specificity-1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-23 14-34-49_BR100135_Allplex GI_B1_TCF_specificity-2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-23 14-35-01_BR100172_Allplex GI_B1_TCF_specificity-3'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-24 10-10-02_BR100135_Allplex GI_B1_TCF_specificity-1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-24 10-10-34_BR100159_Allplex GI_B1_TCF_specificity-2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-24 10-10-39_BR100172_Allplex GI_B1_TCF_specificity-3'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-27 10-40-40_BR100160_Allplex GI B1_Shelf life_plate 1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-27 10-48-37_BR100172_Allplex GI B1_shelf life_plate 2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-27 14-02-19_BR100136_Allplex GI B1_Shelf life_0M-plate 1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-27 14-03-10_BR100139_Allplex GI B1_Shelf life_0M-plate 2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-03 10-06-26_BR100136_Allplex GI B1_Analytical sensitivity_pV.para'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-03 10-07-06_BR100139_Allplex GI B1_Analytical sensitivity_ptcdB'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-09 10-01-00_BR100136_Allplex GI B1_Interfering substances_negative & Salmonella'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-09 10-09-28_BR100136_Allplex GI B1_Interfeing substances_ipaH, Cco'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-09 10-15-05_CC015842_Allplex GI B1_interfering substances_Yen, Vpara'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-09 10-16-04_CC010436_Allplex GI B1_interfering substances_tcdB, Aver'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-11 14-29-06_BR100136_Allplex GI B1_comparison study-plate 2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-11 15-35-24_CC015842_Allplex GI B1_comparison study-plate 3'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-13 10-36-56_BR100139_Allplex GI B1_Sample stability_4_Cco'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-13 14-27-43_CC015842_Allplex GI B1_Sample stability_4_Aver'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-13 14-28-54_CC010436_Allplex GI B1_Sample stability_4_Styphi'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-16 05-20-28_BR100139_B(I)_D1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-16 09-30-55_BR100396_B(I)_D1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-16 16-45-28_CC013751_B(I)_1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-17 17-35-09_BR100136_Allplex GI B1_Sample stability_4_V.pa'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-18 05-45-04_CC009366_B(I)_D2_PRE'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-18 21-31-56_BR100139_B(I)_D2_1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-20 23-12-44_BR100139_B(I)_D3-1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-20 23-12-44_CC009366_B(I)_D3-1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-23 10-09-22_CC009366_B(I)_D4-1'}
# {'unique_wells': 64, 'unique_signals': 64.0, 'name': 'admin_2015-03-23 15-20-53_CC010436_Allplex GI B1_Sample stability_-20_1M(target 1,2,3,4)'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-23 18-23-41_CC010436_Allplex GI B1_Sample stability_-20_1M(target5,6,7)'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-25 08-32-59_CC013751_B(I)_D5'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-25 14-44-57_BR100139_B(I)_D5-1'}
# {'unique_wells': 78, 'unique_signals': 78.0, 'name': 'admin_2015-04-02 10-31-09_BR100134_GI_Bacteria 1_Comparison Test(Qiagen,GeneAll,easyMAG,NIMBUS)'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 14-04-12_BR100171_GI_B1_ACC_tcdB-2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 17-43-01_BR100136_Allplex GI B1_Accelerated_Yer-2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 17-45-34_BR100168_GI_B1_ACC_Yer-1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 17-58-47_BR100134_Allplex GI B1_Accelerated_Cco-2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 17-59-32_CC009371_Allplex GI B1_Accelerated_Cco-1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-07 13-49-58_BR100136_GI_B1_ACC_V.para-1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-07 17-16-28_CC010424_GI_B1_ACC_A.vero-2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-07 17-16-56_BR100136_Allplex GI B1_Accelerated_PC,NC'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-07 17-27-05_BR100135_GI_B1_ACC_S.typh-2'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-14 10-50-37_BR100394_repeat_B(I)_2D_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-15 17-57-23_CC010436_REPEAT_b(I)_3D_PM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-16 10-58-14_CC013751_REPEAT_b(I)_4D_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-17 17-03-54_BR100396_repeat_B(I)_5D_PM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-20 10-09-39_BR100394_repeat_B(I)_6D_AM'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-21 15-22-47_BR100136_GI_B1_In-use_TcdB_Ave'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-22 16-16-54_BR100139_repeat_B(I)_8D_PM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-23 18-34-15_BR100392_repeat_B(I)_9D_PM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-24 10-45-53_BR100135_repeat_B(I)_10D_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-27 10-48-00_CC009366_repeat_B(I)_11D_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-27 18-46-45_CC010436_repeat_B(I)_11D_PM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-28 18-52-07_BR100139_repeat_B(I)_12D_PM'}
# {'unique_wells': 6, 'unique_signals': 6.0, 'name': 'admin_2015-04-29 12-58-02_BR100135_repeat_B(I)_13D_CdB_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-06 10-58-54_CC009366_repeat_B(I)_15D_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-07 10-42-43_BR100392_16D_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-11 10-02-46_BR100386_repeat_B(I)_18D_AM'}
# {'unique_wells': 42, 'unique_signals': 42.0, 'name': 'admin_2015-05-11 17-45-31_CC013751_18D_PM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-12 10-33-59_CC010436_repeat_B(I)_19D_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-12 18-35-57_CC013751_repeat_B(I)_19D_PM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-13 10-09-17_BR100139_repeat_B(I)_20D_AM'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-13 17-59-31_BR100172_repeat_B(I)_20D_PM'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-05-27 10-49-29_BR100135_Allplex GI B1_shelf life_3M_plate 1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-05-27 10-49-29_BR100135_Allplex GI B1_shelf life_plate 1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-05-27 10-49-52_BR100159_Allplex GI B1_shelf life_3M_plate 2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-08-27 10-55-48_BR100171_Allplex GI B1_shelf life_6M_plate 2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-08-27 10-56-24_BR100858_Allplex GI B1_shelf life_plate 1'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-11-27 15-01-48_BR100171_Allplex GI B1_shelf life_9M_plate 2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-11-27 15-03-31_BR100858_Allplex GI B1_shelf life_9M_plate 1'}
# {'unique_wells': 94, 'unique_signals': 94.0, 'name': 'admin_2015-12-14 10-29-45_BR100392_GI-B(I)_LoD_8strip'}
# {'unique_wells': 94, 'unique_signals': 94.0, 'name': 'admin_2015-12-14 10-30-28_BR100139_GI-B(I)_LoD_8strip'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-12-17 10-10-31_CC010436_GI-B(I)_clinical_8strip'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2016-03-27 11-21-54_BR100139_Allplex_GI_B1 shlf life_13M'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2016-03-27 15-05-51_BR100139_Allplex_GI_B1 shelf life_13M_plate2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2016-04-27 15-05-51_BR100139_Allplex_GI_B1 shelf life_plate2'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2017-02-09 10-39-42_BR100826 GI9801X MOM 소량 반제품1 NC'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': 'admin_2017-02-09 11-22-33_BR101472 GI9801X MOM 소량반제품1 민감도 (Aela-1,Ahyd,Avero)'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-02-09 13-43-27_BR100550 GI9801X MOM 소량반제품1 민감도 (SHI, CCO,CJE)'}
# {'unique_wells': 64, 'unique_signals': 64.0, 'name': 'admin_2017-02-09 14-22-48_BR101644 GI9701X MOM 소량반제품1 민감도 (PXS, YER)'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-02-09 14-23-15_BR101645 GI9701X MOM 소량반제품1 민감도 (STYPHY, SBONG2, VCHOL)'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': 'admin_2017-02-20 11-16-01_BR101644 GI9801X MOM 반제품1 민감도(AVERO, CDB,AELAL)'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': 'admin_2017-02-20 11-23-53_BR101459 GI9801XY MOM 반제품1 민감도 (cje, yer, styphi)'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': 'admin_2017-02-20 11-28-16_BR101472 GI9801XY MOM 반제품1 민감도 (sbong, vckol, IC)'}
# {'unique_wells': 56, 'unique_signals': 56.0, 'name': 'admin_2017-02-20 11-32-22_BR100558 GI9801XY MOM 반제품1 민감도 (shi, cco)'}
# {'unique_wells': 42, 'unique_signals': 42.0, 'name': 'admin_2017-02-21 14-40-46_BR101567 GI9801X MOM 반제품1 민감도 재실험(AELA)'}
# {'unique_wells': 20, 'unique_signals': 20.0, 'name': 'admin_2017-02-27 09-54-25_BR100550 GI9801X PC MOM 반제품2'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-05-29 11-30-27_BR101472 GI9801XY MOM 반제품1 NC TEST'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-05-29 14-03-21_BR100550 GI9801XY MOM 반제품1 민감도 (CdB, Vvul)'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2017-05-29 14-09-43_BR100355 GI9801XY MOM 반제품1 민감도 (Aela-1)'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-05-29 14-33-14_BR101472 GI9801XY MOM 반제품1 민감도(Cco, ShEi)'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-05-30 10-28-11_BR101645 GI9801XY MOM 반제품1 민감도 (Stypi, Sbong)'}
# {'unique_wells': 45, 'unique_signals': 45.0, 'name': 'admin_2017-07-25 10-32-15_BR100558 GI9801Y 완제품QC'}
# {'unique_wells': 6, 'unique_signals': 6.0, 'name': 'admin_2017-10-26 10-14-57_BR100858 GI9801Y 완제품 RETEST-2KIT PC'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2017-10-27 10-11-31_BR100858 GI9801Y 완제품 E,PC CROSS CHECK'}

# %% [markdown]
# ### [After BPN] + [Modified DSP]

# %% [markdown]
# ### [Control DSP]

# %%
parquet_path = './data/GI-B-I/control/computed/config__dsp2_generic/dsp/'
paths = Path.Path(f"{parquet_path}").glob("*.parquet")
paths = sorted(list(paths), key=lambda p: p.name)
GIBI_8strip_control_df = pd.DataFrame()
for path in paths:
    name = path.name[:-8]
    df = pd.read_parquet(path)
    print({'unique_wells':len(df['well'].unique()),'unique_signals': len(df['well'])/4/2,'name':name}) #모든 pcrd파일들 channel 별로 high, low 짝지어 찍혔음
# Out:
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': '2. admin_2017-05-22 14-06-05_BR101459 GI9801XY MOM 소량 반제품1 민감도(Vpara, CdB, Vchol).dsp'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': '4. admin_2017-05-22 14-38-11_BR101644 GI9801XY MOM 소량 반제품1 민감도(Ahyd, Avero, Sbong).dsp'}
# {'unique_wells': 56, 'unique_signals': 56.0, 'name': '5. admin_2017-05-22 14-40-33_BR101645 GI9801XY MOM 소량 반제품1 민감도(Styphi, IC).dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-23 02-32-41_BR100160_Allplex GI_B1_TCF_specificity-1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-23 14-34-49_BR100135_Allplex GI_B1_TCF_specificity-2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-23 14-35-01_BR100172_Allplex GI_B1_TCF_specificity-3.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-24 10-10-02_BR100135_Allplex GI_B1_TCF_specificity-1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-24 10-10-34_BR100159_Allplex GI_B1_TCF_specificity-2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-24 10-10-39_BR100172_Allplex GI_B1_TCF_specificity-3.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-27 10-40-40_BR100160_Allplex GI B1_Shelf life_plate 1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-27 10-48-37_BR100172_Allplex GI B1_shelf life_plate 2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-27 14-02-19_BR100136_Allplex GI B1_Shelf life_0M-plate 1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-02-27 14-03-10_BR100139_Allplex GI B1_Shelf life_0M-plate 2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-03 10-06-26_BR100136_Allplex GI B1_Analytical sensitivity_pV.para.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-03 10-07-06_BR100139_Allplex GI B1_Analytical sensitivity_ptcdB.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-09 10-01-00_BR100136_Allplex GI B1_Interfering substances_negative & Salmonella.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-09 10-09-28_BR100136_Allplex GI B1_Interfeing substances_ipaH, Cco.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-09 10-15-05_CC015842_Allplex GI B1_interfering substances_Yen, Vpara.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-09 10-16-04_CC010436_Allplex GI B1_interfering substances_tcdB, Aver.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-11 14-29-06_BR100136_Allplex GI B1_comparison study-plate 2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-11 15-35-24_CC015842_Allplex GI B1_comparison study-plate 3.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-13 10-36-56_BR100139_Allplex GI B1_Sample stability_4_Cco.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-13 14-27-43_CC015842_Allplex GI B1_Sample stability_4_Aver.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-13 14-28-54_CC010436_Allplex GI B1_Sample stability_4_Styphi.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-16 05-20-28_BR100139_B(I)_D1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-16 09-30-55_BR100396_B(I)_D1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-16 16-45-28_CC013751_B(I)_1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-17 17-35-09_BR100136_Allplex GI B1_Sample stability_4_V.pa.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-18 05-45-04_CC009366_B(I)_D2_PRE.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-18 21-31-56_BR100139_B(I)_D2_1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-20 23-12-44_BR100139_B(I)_D3-1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-20 23-12-44_CC009366_B(I)_D3-1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-23 10-09-22_CC009366_B(I)_D4-1.dsp'}
# {'unique_wells': 64, 'unique_signals': 64.0, 'name': 'admin_2015-03-23 15-20-53_CC010436_Allplex GI B1_Sample stability_-20_1M(target 1,2,3,4).dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-23 18-23-41_CC010436_Allplex GI B1_Sample stability_-20_1M(target5,6,7).dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-25 08-32-59_CC013751_B(I)_D5.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-03-25 14-44-57_BR100139_B(I)_D5-1.dsp'}
# {'unique_wells': 78, 'unique_signals': 78.0, 'name': 'admin_2015-04-02 10-31-09_BR100134_GI_Bacteria 1_Comparison Test(Qiagen,GeneAll,easyMAG,NIMBUS).dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 14-04-12_BR100171_GI_B1_ACC_tcdB-2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 17-43-01_BR100136_Allplex GI B1_Accelerated_Yer-2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 17-45-34_BR100168_GI_B1_ACC_Yer-1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 17-58-47_BR100134_Allplex GI B1_Accelerated_Cco-2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-06 17-59-32_CC009371_Allplex GI B1_Accelerated_Cco-1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-07 13-49-58_BR100136_GI_B1_ACC_V.para-1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-07 17-16-28_CC010424_GI_B1_ACC_A.vero-2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-07 17-16-56_BR100136_Allplex GI B1_Accelerated_PC,NC.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-07 17-27-05_BR100135_GI_B1_ACC_S.typh-2.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-14 10-50-37_BR100394_repeat_B(I)_2D_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-15 17-57-23_CC010436_REPEAT_b(I)_3D_PM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-16 10-58-14_CC013751_REPEAT_b(I)_4D_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-17 17-03-54_BR100396_repeat_B(I)_5D_PM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-20 10-09-39_BR100394_repeat_B(I)_6D_AM.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-04-21 15-22-47_BR100136_GI_B1_In-use_TcdB_Ave.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-22 16-16-54_BR100139_repeat_B(I)_8D_PM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-23 18-34-15_BR100392_repeat_B(I)_9D_PM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-24 10-45-53_BR100135_repeat_B(I)_10D_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-27 10-48-00_CC009366_repeat_B(I)_11D_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-27 18-46-45_CC010436_repeat_B(I)_11D_PM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-04-28 18-52-07_BR100139_repeat_B(I)_12D_PM.dsp'}
# {'unique_wells': 6, 'unique_signals': 6.0, 'name': 'admin_2015-04-29 12-58-02_BR100135_repeat_B(I)_13D_CdB_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-06 10-58-54_CC009366_repeat_B(I)_15D_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-07 10-42-43_BR100392_16D_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-11 10-02-46_BR100386_repeat_B(I)_18D_AM.dsp'}
# {'unique_wells': 42, 'unique_signals': 42.0, 'name': 'admin_2015-05-11 17-45-31_CC013751_18D_PM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-12 10-33-59_CC010436_repeat_B(I)_19D_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-12 18-35-57_CC013751_repeat_B(I)_19D_PM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-13 10-09-17_BR100139_repeat_B(I)_20D_AM.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2015-05-13 17-59-31_BR100172_repeat_B(I)_20D_PM.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-05-27 10-49-29_BR100135_Allplex GI B1_shelf life_3M_plate 1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-05-27 10-49-29_BR100135_Allplex GI B1_shelf life_plate 1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-05-27 10-49-52_BR100159_Allplex GI B1_shelf life_3M_plate 2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-08-27 10-55-48_BR100171_Allplex GI B1_shelf life_6M_plate 2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-08-27 10-56-24_BR100858_Allplex GI B1_shelf life_plate 1.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-11-27 15-01-48_BR100171_Allplex GI B1_shelf life_9M_plate 2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-11-27 15-03-31_BR100858_Allplex GI B1_shelf life_9M_plate 1.dsp'}
# {'unique_wells': 94, 'unique_signals': 94.0, 'name': 'admin_2015-12-14 10-29-45_BR100392_GI-B(I)_LoD_8strip.dsp'}
# {'unique_wells': 94, 'unique_signals': 94.0, 'name': 'admin_2015-12-14 10-30-28_BR100139_GI-B(I)_LoD_8strip.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2015-12-17 10-10-31_CC010436_GI-B(I)_clinical_8strip.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2016-03-27 11-21-54_BR100139_Allplex_GI_B1 shlf life_13M.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2016-03-27 15-05-51_BR100139_Allplex_GI_B1 shelf life_13M_plate2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2016-04-27 15-05-51_BR100139_Allplex_GI_B1 shelf life_plate2.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2017-02-09 10-39-42_BR100826 GI9801X MOM 소량 반제품1 NC.dsp'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': 'admin_2017-02-09 11-22-33_BR101472 GI9801X MOM 소량반제품1 민감도 (Aela-1,Ahyd,Avero).dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-02-09 13-43-27_BR100550 GI9801X MOM 소량반제품1 민감도 (SHI, CCO,CJE).dsp'}
# {'unique_wells': 64, 'unique_signals': 64.0, 'name': 'admin_2017-02-09 14-22-48_BR101644 GI9701X MOM 소량반제품1 민감도 (PXS, YER).dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-02-09 14-23-15_BR101645 GI9701X MOM 소량반제품1 민감도 (STYPHY, SBONG2, VCHOL).dsp'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': 'admin_2017-02-20 11-16-01_BR101644 GI9801X MOM 반제품1 민감도(AVERO, CDB,AELAL).dsp'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': 'admin_2017-02-20 11-23-53_BR101459 GI9801XY MOM 반제품1 민감도 (cje, yer, styphi).dsp'}
# {'unique_wells': 84, 'unique_signals': 84.0, 'name': 'admin_2017-02-20 11-28-16_BR101472 GI9801XY MOM 반제품1 민감도 (sbong, vckol, IC).dsp'}
# {'unique_wells': 56, 'unique_signals': 56.0, 'name': 'admin_2017-02-20 11-32-22_BR100558 GI9801XY MOM 반제품1 민감도 (shi, cco).dsp'}
# {'unique_wells': 42, 'unique_signals': 42.0, 'name': 'admin_2017-02-21 14-40-46_BR101567 GI9801X MOM 반제품1 민감도 재실험(AELA).dsp'}
# {'unique_wells': 20, 'unique_signals': 20.0, 'name': 'admin_2017-02-27 09-54-25_BR100550 GI9801X PC MOM 반제품2.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-05-29 11-30-27_BR101472 GI9801XY MOM 반제품1 NC TEST.dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-05-29 14-03-21_BR100550 GI9801XY MOM 반제품1 민감도 (CdB, Vvul).dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2017-05-29 14-09-43_BR100355 GI9801XY MOM 반제품1 민감도 (Aela-1).dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-05-29 14-33-14_BR101472 GI9801XY MOM 반제품1 민감도(Cco, ShEi).dsp'}
# {'unique_wells': 96, 'unique_signals': 96.0, 'name': 'admin_2017-05-30 10-28-11_BR101645 GI9801XY MOM 반제품1 민감도 (Stypi, Sbong).dsp'}
# {'unique_wells': 45, 'unique_signals': 45.0, 'name': 'admin_2017-07-25 10-32-15_BR100558 GI9801Y 완제품QC.dsp'}
# {'unique_wells': 6, 'unique_signals': 6.0, 'name': 'admin_2017-10-26 10-14-57_BR100858 GI9801Y 완제품 RETEST-2KIT PC.dsp'}
# {'unique_wells': 48, 'unique_signals': 48.0, 'name': 'admin_2017-10-27 10-11-31_BR100858 GI9801Y 완제품 E,PC CROSS CHECK.dsp'}

# %% [markdown]
# ### [Auto]

# %% [markdown]
# ### [CFX]

# %% [markdown]
# ### [Strep+1]

# %% [markdown]
# ## 2. dsp-executer 단계

# %% [markdown]
# ### [After BPN] + [Modified DSP]

# %% [markdown]
# ### [Control DSP]

# %% [markdown]
# ### [Auto]

# %% [markdown]
# ### [CFX]

# %% [markdown]
# ### [Strep+1]
